# %% [markdown]
# # MNIST
# MNIST 데이터셋에 Bagging, Random Forest, Boosting을 적용하여 각각의 예측 정확도를 비교하였습니다.

# %%
import warnings
import os
import pandas as pd
import numpy as np
import torchvision.datasets as datasets
from sklearn.model_selection import train_test_split
import torch

# %%
trainset = datasets.MNIST(root='./data', train=True, download=False)
testset = datasets.MNIST(root='./data', train=False, download=False)

X_train, y_train = trainset.data.numpy().reshape(-1, 28*28), trainset.targets.numpy()
X_test, y_test = testset.data.numpy().reshape(-1, 28*28),testset.targets.numpy()

X = {'train':X_train, 'test':X_test}
y = {'train':y_train, 'test':y_test}

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
# Out:
# c:\Users\DH\Anaconda3\envs\pynew\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
# Bagging
bg = BaggingClassifier()

# Random Forest
rf = RandomForestClassifier()

# Boosting
ada = AdaBoostClassifier()
xgb = XGBClassifier()
lgb = LGBMClassifier()
gbm = GradientBoostingClassifier()
cat = CatBoostClassifier()

# %%
# Bagging
bg.fit(X_train, y_train)

# Random Forest
rf.fit(X_train, y_train)

# Boosting
ada.fit(X_train, y_train)
gbm.fit(X_train, y_train)
xgb.fit(X_train, y_train)
lgb.fit(X_train, y_train)
cat.fit(X_train, y_train)
# Out:
# c:\Users\DH\Anaconda3\envs\pynew\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:24:44] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Learning rate set to 0.097501
# 0:	learn: 2.0000537	total: 924ms	remaining: 15m 22s
# 1:	learn: 1.8077927	total: 1.75s	remaining: 14m 35s
# 2:	learn: 1.6561870	total: 2.6s	remaining: 14m 22s
# ...

# %%
y_pred_bg = bg.predict(X_test)

y_pred_rf = rf.predict(X_test)

y_pred_ada = ada.predict(X_test)
y_pred_gbm = gbm.predict(X_test)
y_pred_xgb = xgb.predict(X_test)
y_pred_lgb = lgb.predict(X_test)
y_pred_cat = cat.predict(X_test)

# %%
# Bagging
print(f"Bagging 예측 정확도: {accuracy_score(y_test, y_pred_bg)}")

# Random Forest
print(f"Random Forest 예측 정확도: {accuracy_score(y_test, y_pred_rf)}")

# Boosting
print(f"AdaBoost 예측 정확도: {accuracy_score(y_test, y_pred_ada)}")
print(f"GBM 예측 정확도: {accuracy_score(y_test, y_pred_gbm)}")
print(f"XGBoost 예측 정확도: {accuracy_score(y_test, y_pred_xgb)}")
print(f"LightGBM 예측 정확도: {accuracy_score(y_test, y_pred_lgb)}")
print(f"CatBoost 예측 정확도: {accuracy_score(y_test, y_pred_cat)}")
# Out:
# Bagging 예측 정확도: 0.9443
# Random Forest 예측 정확도: 0.9698
# AdaBoost 예측 정확도: 0.7299
# GBM 예측 정확도: 0.9459
# XGBoost 예측 정확도: 0.978
# LightGBM 예측 정확도: 0.9774
# CatBoost 예측 정확도: 0.9746

# %% [markdown]
# ## 실험결과
# MNIST 데이터셋의 경우 최적의 파라미터를 찾고자 grid search를 사용하면 시간이 너무 오래 걸려 사용하지 않았습니다. 파라미터를 default 값으로 사용하여 예측 정확도를 비교한 결과 LightGBM과 CatBoost가 가장 우수했으며 AdaBoost의 경우엔 0.72로 정확도가 크게 떨어지는 것을 확인할 수 있었습니다.
